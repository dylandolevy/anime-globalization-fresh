# %%
# notebooks/01_load_preview.ipynb cell 1
import sys, os
from pathlib import Path
import pandas as pd
print("Python:", sys.executable)
print("cwd:", Path.cwd())

# Look for raw files
for p in sorted(Path("data/raw").glob("*")):
    print(p.name, "-", p.stat().st_size)
